# %%
from ssms.basic_simulators.simulator import simulator
import numpy as np
import pandas as pd

# Specify parameters
v_true, a_true, z_true, t_true = [0.5, 1.5, 0.5, 0.2]


# Simulate data
sim_out = simulator(
    theta=[v_true, a_true, z_true, t_true],  # parameter list
    model="ddm",  # specify model (many are included in ssms)
    n_samples=10,  # number of samples for each set of parameters
    random_state=42
)

# Turn into nice dataset
# Turn data into a pandas dataframe
dataset = pd.DataFrame(
    np.column_stack([sim_out["rts"][:, 0], sim_out["choices"][:, 0]]),
    columns=["rt", "response"],
)

dataset
# Out:
#          rt  response
# 0  1.091585       1.0
# 1  5.209785       1.0
# 2  0.749647      -1.0
# 3  1.152154       1.0
# 4  7.569376       1.0
# 5  0.548372      -1.0
# 6  5.189809       1.0
# 7  1.525539       1.0
# 8  1.515226       1.0
# 9  6.858074       1.0
